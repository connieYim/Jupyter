# %%
'''
ETF

ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 
거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 
거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 
공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 
참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 
분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 
펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
'''

#  JSON 형태로 data 전송하기

import pandas as pd
import numpy as np
import requests

# %%
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"


response = requests.get(url)
print('response :',response)
print('response :',type(response))
response.text

# %%
# response 를 JSON 형태로 만들기
# response 객체의 json() 메소드는 
# 문자열 형태의 JSON 을 python 의 dictionary 로 만들어줌

#  문자열 형태의 JSON -->  python 의 dictionary 
etf_json = response.json()
print(type(etf_json))

# %%
etf_json
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 34210,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -0.67,
#     'nav': 34284.0,
#     'threeMonthEarnRate': 4.6522,
#     'quant': 2291401,
#     'amonut': 78594,
#     'marketSum': 60278},
#    {'itemcode': '357870',
#     'etfTabCode': 6,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 52780,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.04,
#     'nav': 52780.0,
#     'threeMonthEarnRate': 0.9084,
#     'quant': 148104,
#     'amonut': 7816,
#     'marketSum': 51750},
#    {'itemcode': '423160',
#     'etfTabCode': 6,
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'nowVal': 103790,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 103790.0,
#     'threeMonthEarnRate': 0.909,
#     'quant': 87328,
#     'amonut': 9063,
#     'marketSum': 35186},
# ...

# %%
etfItemList = etf_json['result']['etfItemList']
len(etfItemList)
# Out:
# 748

# %%
print(type(etfItemList))
# Out:
# <class 'list'>

# %%
'''
list  -->  DataFrame
'''
etfItemList_df = pd.DataFrame(etfItemList)
etfItemList_df.shape
# Out:
# (748, 12)

# %%
etfItemList_df[:3]
# Out:
#   itemcode  etfTabCode             itemname  nowVal risefall  changeVal  \
# 0   069500           1            KODEX 200   34210        5       -230
# 1   357870           6  TIGER CD금리투자KIS(합성)   52780        2         20
# 2   423160           6  KODEX KOFR금리액티브(합성)  103790        2          5
#
#    changeRate       nav  threeMonthEarnRate    quant  amonut  marketSum
# 0       -0.67   34284.0              4.6522  2291401   78594      60278
# 1        0.04   52780.0              0.9084   148104    7816      51750
# 2        0.00  103790.0              0.9090    87328    9063      35186

# %%
import datetime

today = datetime.datetime.today()
today = today.strftime("%Y-%m-%d")
today
# Out:
# '2023-08-03'

# %%
file_name = f'etf_{today}_raw.csv'
file_name
# Out:
# 'etf_2023-08-03_raw.csv'

# %%
etfItemList_df.to_csv(file_name, index=False)

# %%
pd.read_csv('etf_2023-08-03_raw.csv')
# Out:
#      itemcode  etfTabCode               itemname  nowVal  risefall  changeVal  \
# 0       69500           1              KODEX 200   34210         5       -230
# 1      357870           6    TIGER CD금리투자KIS(합성)   52780         2         20
# 2      423160           6    KODEX KOFR금리액티브(합성)  103790         2          5
# 3      273130           6   KODEX 종합채권(AA-이상)액티브  104625         5        -55
# 4      371460           4  TIGER 차이나전기차SOLACTIVE   10185         2         55
# ..        ...         ...                    ...     ...       ...        ...
# 743    433870           7     ARIRANG TDF2050액티브   10860         2         20
# 744    315480           2    KBSTAR 200커뮤니케이션서비스   10905         5       -135
# 745    287330           2        KBSTAR 200생활소비재    5760         5         -5
# 746    287320           2          KBSTAR 200산업재   12195         5       -135
# 747    301440           2         ARIRANG 코스피중형주   10575         3          0
#
# ...
