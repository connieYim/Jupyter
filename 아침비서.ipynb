# %%
import requests
from bs4 import BeautifulSoup
import re

def create_soup(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"} 
    res = requests.get(url, headers=headers)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "lxml")
    return soup

def scrpae_weather():
    print("[오늘의날씨]")
    print()
    url='https://www.google.com/search?q=%EC%84%9C%EC%9A%B8%EB%82%A0%EC%94%A8&oq=%EC%84%9C%EC%9A%B8%EB%82%A0%EC%94%A8&gs_lcrp=EgZjaHJvbWUyDwgAEEUYORiDARixAxiABDIMCAEQABhDGIAEGIoFMgcIAhAAGIAEMgcIAxAAGIAEMgcIBBAAGIAEMgcIBRAAGIAEMgcIBhAAGIAEMgcIBxAAGIAEMgcICBAAGIAEMgcICRAAGIAEqAIAsAIA&sourceid=chrome&ie=UTF-8'
    soup = create_soup(url)
        
    cast=soup.find("span",attrs={"id":"wob_dc"}).get_text()
    cur_temp=soup.find("span",attrs={"class":"wob_t q8U8x"}).get_text()
    lowest=soup.find("div",class_='QrNVmd ZXCv8e')
    lowest_temp=lowest.find_all("span",class_='wob_t')[0].get_text()

    pp=soup.find("span",id='wob_pp').get_text()

    print("현재날씨:",cast)
    print("현재온도:{} 오늘의 최저온도:{} 강수량{}".format(cur_temp,lowest_temp,pp))

scrpae_weather()
print()

def scrpae_news():
    print("[오늘의헤드라인뉴스]")
    print()
    url='https://news.daum.net/'
    soup = create_soup(url)
   
    news_items = soup.find("ul", class_='list_newsissue').find_all("li",limit=5)
    for index, news_item in enumerate(news_items, start=1):
        # if index > 5:
        #     break  # Exit the loop after extracting 5 news titles
        strong_tag = news_item.find("strong", class_='tit_g')
        if strong_tag:
            title_text = strong_tag.get_text(strip=True)
        link = news_item.find("a")["href"]   

        print(f"News {index}: {title_text}")
        print(f"Link :{link}")
       
scrpae_news()
print()

def scrpae_news_it():
    print("[오늘의IT뉴스]")
    print()
    url='https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105'
    soup = create_soup(url)
   
    news_items = soup.find("ul", class_='sh_list').find_all("li",limit=5)
    for index, news_it in enumerate(news_items):
        # if index > 5:
        #     break  # Exit the loop after extracting 5 news titles
        title = news_it.find("a",class_="sh_text_headline nclicks(cls_sci.clsart)").get_text().strip()
        link = news_it.find("a")["href"]   

        print("IT뉴스 {}:{}".format(index+1,title))
        print(f"Link :{link}")
        # print_news(index,title,link)
       
scrpae_news_it()
print()
# Out:
# [오늘의날씨]
#
# 현재날씨: 맑음
# 현재온도:8 오늘의 최저온도:-3 강수량0%
#
# [오늘의헤드라인뉴스]
#
# News 1: 해썹 위생‧안전 시설개선자금 신청하세요
# Link :https://v.daum.net/v/20240131172602860
# News 2: 폭설 속 쓰러진 60대…응급처치로 소중한 생명 구한 전북 정읍 공무원
# Link :https://v.daum.net/v/20240131171110392
# News 3: [영상] "윤석열 결탁세력이 KBS 장악 못하니 임명동의제 망가뜨리려는 것"
# Link :https://v.daum.net/v/20240131172330772
# News 4: 이재명, 내달 4일 문재인 전 대통령 예방 검토
# Link :https://v.daum.net/v/20240131172344776
# News 5: "가이드라인 정해야 AI법률 서비스 큰다"
# Link :https://v.daum.net/v/20240131172003661
#
# [오늘의IT뉴스]
#
# IT뉴스 1:게임이용자협회 "이용자 보호 정책 환영…국내 대리인 제도 시급"
# Link :https://n.news.naver.com/mnews/article/374/0000368806?sid=105
# IT뉴스 2:"법조계, 기술침투 가장 늦어…법률AI 가이드라인 필요"
# Link :https://n.news.naver.com/mnews/article/018/0005665009?sid=105
# IT뉴스 3:애플 전문가 "올해 쉽지 않다, 구조적 문제…갤S24는 출하량 늘 것"
# Link :https://n.news.naver.com/mnews/article/008/0004993106?sid=105
# IT뉴스 4:방통위, 갤럭시S24 공시지원금 확대 재차 요청
# Link :https://n.news.naver.com/mnews/article/366/0000966986?sid=105
# IT뉴스 5:하이퍼클로바X 생태계 넓힌다…네이버클라우드, 생성형 AI 도입 지원
# Link :https://n.news.naver.com/mnews/article/277/0005374093?sid=105
